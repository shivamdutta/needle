# %%
import pandas as pd
import pickle
import datetime as dt
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 5000)

# %%
#from LogIn import LogIn
#kite = LogIn().return_kite_obj()

# %%
budget_df = pd.read_csv('budget.csv')

# %%
budget_df
# Out:
#         instrument  budget  return
# 0    NSE:UNIONBANK     400    0.02
# 1      NSE:DCBBANK     400    0.02
# 2      NSE:YESBANK     400    0.02
# 3        NSE:WIPRO     400    0.02
# 4    NSE:TATASTEEL     400    0.02
# 5         NSE:SBIN     400    0.02
# 6          NSE:PNB     400    0.02
# 7         NSE:ONGC     400    0.02
# 8          NSE:OIL     400    0.02
# 9         NSE:NTPC     400    0.02
# 10         NSE:BEL     400    0.02
# 11      NSE:BIOCON     400    0.02
# 12       NSE:CANBK     400    0.02
# 13  NSE:CASTROLIND     400    0.02
# 14    NSE:CHOLAFIN     400    0.02
# 15   NSE:COALINDIA     400    0.02
# 16  NSE:ENGINERSIN     400    0.02
# 17    NSE:EXIDEIND     400    0.02
# 18    NSE:JSWSTEEL     400    0.02
# 19  NSE:MANAPPURAM     400    0.02
# 20        NSE:SAIL     400    0.02
# 21      NSE:RECLTD     400    0.02
# 22        NSE:NMDC     400    0.02
# 23        NSE:MFSL     500    0.02
# 24        NSE:IDBI     400    0.02
# 25      NSE:ARVIND     400    0.02
# 26        NSE:BHEL     400    0.02
# 27  NSE:TATAMTRDVR     400    0.02
# 28   NSE:TATAPOWER     400    0.02
# 29  NSE:ADANIPOWER     400    0.02
# 30       NSE:BSOFT     400    0.02
# 31    NSE:ASHOKLEY     400    0.02
# 32         NSE:NCC     400    0.02
# 33   NSE:BANKINDIA     400    0.02
# 34  NSE:FEDERALBNK     400    0.02
# 35  NSE:MOTHERSUMI     400    0.02
# 36  NSE:BANKBARODA     400    0.02
# 37  NSE:JINDALSTEL     400    0.02
# 38       NSE:L&TFH     400    0.02
# 39         NSE:PFC     400    0.02
# 40     NSE:EQUITAS     400    0.02
# 41  NSE:TATAMOTORS     400    0.02
# 42         NSE:IOC     400    0.02
# 43    NSE:ADANIENT     400    0.02
# 44        NSE:GAIL     400    0.02
# 45        NSE:VEDL     400    0.02
# 46  NSE:APOLLOTYRE     400    0.02
# 47         NSE:DLF     400    0.02
# 48    NSE:HINDALCO     400    0.02
# 49   NSE:AMBUJACEM     400    0.02
# 50    NSE:HINDZINC     400    0.02
# 51    NSE:CADILAHC     400    0.02
# 52   NSE:POWERGRID     400    0.02
# 53   NSE:HINDPETRO     400    0.02
# 54    NSE:INFRATEL     400    0.02
# 55         NSE:ITC     400    0.02
# 56    NSE:PETRONET     400    0.02
# 57  NSE:TATAGLOBAL     400    0.02
# 58     NSE:UJJIVAN     400    0.02
# 59  NSE:TORNTPOWER     400    0.02
# 60         NSE:IGL     400    0.02
# 61  NSE:ADANIPORTS     400    0.02
# 62  NSE:BERGEPAINT     400    0.02
# 63        NSE:BPCL     400    0.02
# 64        NSE:ZEEL     400    0.02
# 65    NSE:GLENMARK     400    0.02
# 66  NSE:BHARTIARTL     400    0.02
# 67    NSE:TVSMOTOR     400    0.02
# 68    NSE:HEXAWARE     400    0.02
# 69  NSE:ICICIPRULI     400    0.02

# %% [markdown]
# # Inputs

# %%
from_year = 2015
to_year = 2018

# %%
leverage = 15
exit_time = dt.time(15, 10)

# %% [markdown]
# # Process

# %%
# Download data of all companies
download = False

if download:
    
    for year in range(from_year, to_year+1):
        
        from_date = '{}-01-01'.format(year)
        to_date = '{}-12-31'.format(year)
        print(from_date, to_date)
        for instrument in budget_df.instrument.tolist():

            try:
                print('------------')
                print(instrument)
                instrument_token = kite.ohlc(instrument)[instrument]['instrument_token']
                data = kite.historical_data(instrument_token=instrument_token, from_date=from_date, to_date=to_date, interval='minute', continuous=False)
                data_df = pd.DataFrame(data)
                data_df.to_pickle('./data/{}_{}_{}.pkl'.format(instrument, from_date, to_date))

            except Exception as ex:
                print('Failed for {} : {}'.format(instrument, ex))

# %%
def get_clean_data(instrument, from_year, to_year):
    
    print(instrument)
    
    all_data_df = pd.DataFrame()
    
    for year in range(from_year, to_year+1):
        
        print(year)
        
        from_date = '{}-01-01'.format(year)
        to_date = '{}-12-31'.format(year)
        
        data_df = pd.read_pickle('./data/{}_{}_{}.pkl'.format(instrument, from_date, to_date))
        data_df.rename(columns={'date':'timestamp'}, inplace=True)
        data_df['date'] = data_df['timestamp'].dt.date
        data_df['day'] = data_df['timestamp'].dt.day_name()
        print(len(data_df))

        sanity_check = data_df.groupby('date').count().reset_index()
        incomplete_data_days = sanity_check[sanity_check['volume']<300]
        print(incomplete_data_days)

        data_df = data_df[~data_df['date'].isin(incomplete_data_days.date.tolist())]
        data_df['instrument'] = instrument
        print(len(data_df)/375)
        
        all_data_df = all_data_df.append(data_df, ignore_index=True)
        
    return all_data_df

# %%
header_list = ['instrument', 'high_prev', 'low_prev', 'open_today', 'condition', 'transaction_type', 'trade_number', 'level', 'budget', 'return', 'daily_khwab', 'actual_khwab', 'quantity', 'budget_required', 'price', 'trigger_price', 'squareoff', 'stoploss', 'order_id', 'timestamp', 'order_type', 'status', 'profit', 'pl_tag', 'flag', 'adhoora_khwab']

# %%
par_1 = 0.55
par_2 = 0.675

# %%
calculate = True

if calculate:
    
    all_trades = pd.DataFrame(columns=header_list)

    for instrument in budget_df.instrument.tolist():

        try:
            all_data_df = get_clean_data(instrument, from_year, to_year)

            for i in range(len(all_data_df.date.unique().tolist())-1):

                date_prev = all_data_df.date.unique().tolist()[i]
                data_prev = all_data_df[all_data_df['date']==date_prev]
                open_prev = data_prev.open.iloc[0]
                close_prev = data_prev.open.iloc[-1]
                high_prev = data_prev.high.max()
                low_prev = data_prev.low.min()

                date_today = all_data_df.date.unique().tolist()[i+1]
                data_today = all_data_df[all_data_df['date']==date_today]

                # Trim beyond exit time
                data_today = data_today[data_today['timestamp'].dt.time<exit_time]
                open_today = data_today.open.iloc[0]

                if (open_today > high_prev) & (open_today < 1.15 * high_prev):

                    condition = 'high'
                    transaction_type = 'buy'

                elif (open_today < low_prev) & (open_today > 0.85 * low_prev):

                    condition = 'low'
                    transaction_type = 'sell'

                else:

                    condition = None
                    transaction_type = None

                if condition is not None:

                    valid_trades = all_trades[(all_trades['instrument']==instrument) & (all_trades['condition']==condition) & (all_trades['status']=='complete')]
                    last_valid_trade = valid_trades[valid_trades['trade_number']==valid_trades['trade_number'].max()]

                    # Calculate trade number
                    if len(last_valid_trade):
                        trade_number = int(last_valid_trade['trade_number']) + 1
                    else:
                        trade_number = 1

                    # Calculate level
                    if len(last_valid_trade):
                        if float(last_valid_trade['pl_tag'])==1.0:
                            level = 1
                        else:
                            level = float(last_valid_trade['level']) + 1
                    else:
                        level = 1

                    # Calculate budget and return
                    if level==1:
                        budget = float(budget_df[budget_df['instrument']==instrument]['budget'])
                        return_ = float(budget_df[budget_df['instrument']==instrument]['return'])
                    else:
                        budget = float(last_valid_trade['budget'])
                        return_ = float(last_valid_trade['return'])

                    # Calculate daily khwab
                    if len(last_valid_trade):
                        if int(last_valid_trade['flag'])==1:
                            daily_khwab = 0
                        elif int(last_valid_trade['flag'])==-1:
                            daily_khwab = 0 # round(return_ * budget, 2)
                        else:
                            daily_khwab = 0
                    else:
                        daily_khwab = 0

                    # Calculate actual khwab
                    if len(last_valid_trade):
                        actual_khwab = max(round(float(last_valid_trade['adhoora_khwab']) + daily_khwab, 2), 0)
                    else:
                        actual_khwab = 0

                    # Calculate quantity
                    quantity = max(int(actual_khwab/(par_1 * return_ * open_today)), int(budget/open_today))
                    
                    # Calculate budget required
                    budget_required = round(quantity * open_today, 2)

                    # Calculate price and trigger price
                    if transaction_type=='buy':
                        price = round(open_today + 0.05 * max(round(20 * 0.0010 * open_today), 2), 2)
                        trigger_price = round(open_today + 0.05 * max(round(20 * 0.0005 * open_today),1), 2)
                    else:
                        price = round(open_today - 0.05 * max(round(20 * 0.0010 * open_today), 2), 2)
                        trigger_price = round(open_today - 0.05 * max(round(20 * 0.0005 * open_today),1), 2)

                    # Calculate square off and stoploss
                    squareoff = round(par_2 * return_ * price, 1)
                    stoploss = round(return_ * price, 1)

                    # Calculate order_id, order_type
                    order_id = trade_number
                    order_type = 'SL'

                    # Calculate timestamp, status and profit
                    if transaction_type=='buy':

                        if data_today.high.max() < trigger_price:

                            timestamp = data_today.timestamp.iloc[0]
                            status = 'incomplete'
                            profit = 0

                        else:

                            status = 'complete'
                            for index, row in data_today.iterrows():

                                if row['high'] > price + squareoff:
                                    timestamp = row['timestamp']
                                    profit = round(squareoff * quantity, 2)
                                    break

                                elif row['low'] < price - stoploss:
                                    timestamp = row['timestamp']
                                    profit = round(-1 * stoploss * quantity, 2)
                                    break

                                else:
                                    timestamp = row['timestamp']
                                    profit = round((row['close']-price) * quantity, 2)

                    else:

                        if data_today.low.min() > trigger_price:
                            timestamp = data_today.timestamp.iloc[0]
                            status = 'incomplete'
                            profit = 0            

                        else:

                            status = 'complete'
                            for index, row in data_today.iterrows():

                                if row['low'] < price - squareoff:
                                    timestamp = row['timestamp']
                                    profit = round(squareoff * quantity, 2)
                                    break

                                elif row['high'] > price + stoploss:
                                    timestamp = row['timestamp']
                                    profit = round(-1 * stoploss * quantity, 2)
                                    break

                                else:
                                    timestamp = row['timestamp']
                                    profit = round((price - row['close']) * quantity, 2)

                    # Calculate P/L tag
                    if profit>=0:
                        pl_tag = round(round(float(profit), 2) / (float(squareoff) * float(quantity)), 1)
                    else:
                        pl_tag = round(round(float(profit), 2) / (float(stoploss) * float(quantity)), 1)
                        
                    # Calculate flag
                    if (pl_tag>=1):
                        flag = 1
                    elif (pl_tag<=-1):
                        flag = -1
                    else:
                        flag = 0

                    # Calculate adhoora khwab
                    adhoora_khwab = round(float(actual_khwab) - profit, 2)

                    trades_today = pd.DataFrame(data={'instrument':[instrument], 
                                                      'high_prev':[high_prev], 
                                                      'low_prev':[low_prev], 
                                                      'open_today':[open_today], 
                                                      'condition':[condition], 
                                                      'transaction_type':[transaction_type], 
                                                      'trade_number':[trade_number], 
                                                      'level':[level], 
                                                      'budget':[budget], 
                                                      'return':[return_], 
                                                      'daily_khwab':[daily_khwab], 
                                                      'actual_khwab':[actual_khwab], 
                                                      'quantity':[quantity], 
                                                      'budget_required':[budget_required], 
                                                      'price':[price], 
                                                      'trigger_price':[trigger_price], 
                                                      'squareoff':[squareoff], 
                                                      'stoploss':[stoploss], 
                                                      'order_id':[order_id], 
                                                      'timestamp':[timestamp], 
                                                      'order_type':[order_type], 
                                                      'status':[status], 
                                                      'profit':[profit], 
                                                      'pl_tag':[pl_tag], 
                                                      'flag':[flag], 
                                                      'adhoora_khwab':[adhoora_khwab]
                                                     })

                    all_trades = all_trades.append(trades_today, ignore_index = True)
        except Exception as ex:
            print('Failed calculation for {} : {}'.format(instrument, ex))
            
    all_trades.to_pickle('all_trades_oneper_final_{}_{}_{}_{}.pkl'.format(from_year, to_year, par_1, par_2))
    all_trades.to_csv('all_trades_oneper_final_{}_{}_{}_{}.pkl'.format(from_year, to_year, par_1, par_2))
    
else:
    
    all_trades = pd.read_pickle('all_trades_oneper_final_{}_{}.pkl'.format(from_year, to_year))
# Out:
# NSE:UNIONBANK
# 2015
# 84725
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.768
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:DCBBANK
# 2015
# 84732
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78666666666666
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91934
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 244.99733333333333
# NSE:YESBANK
# 2015
# 84724
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76533333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:WIPRO
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:TATASTEEL
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:TATASTEEL : float division by zero
# NSE:SBIN
# 2015
# 84729
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77866666666668
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:PNB
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:ONGC
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:OIL
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:NTPC
# 2015
# 84722
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:BEL
# 2015
# 84729
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77866666666668
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:BIOCON
# 2015
# 84729
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77866666666668
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:CANBK
# 2015
# 84732
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78666666666666
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:CANBK : float division by zero
# NSE:CASTROLIND
# 2015
# 84734
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.792
# 2016
# 91933
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 244.99466666666666
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91933
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 244.99466666666666
# NSE:CHOLAFIN
# 2015
# 84598
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     61         61    61   61    61      61   61
# 225.432
# 2016
# 91837
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 244.73866666666666
# 2017
# 92484
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 245.984
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:COALINDIA
# 2015
# 84732
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78666666666666
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:COALINDIA : float division by zero
# NSE:ENGINERSIN
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:EXIDEIND
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:JSWSTEEL
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:JSWSTEEL : float division by zero
# NSE:MANAPPURAM
# 2015
# 84724
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76533333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:SAIL
# 2015
# 84724
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76533333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:RECLTD
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:NMDC
# 2015
# 84723
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76266666666666
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:MFSL
# 2015
# 84724
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76533333333333
# 2016
# 88107
#            date  close  timestamp  high  low  open  volume  day
# 192  2016-10-30     60         60    60   60    60      60   60
# 234.792
# 2017
# 92487
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 245.992
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:MFSL : float division by zero
# NSE:IDBI
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:ARVIND
# 2015
# 84734
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.792
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91906
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 244.92266666666666
# Failed calculation for NSE:ARVIND : float division by zero
# NSE:BHEL
# 2015
# 84730
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78133333333332
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:TATAMTRDVR
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:TATAPOWER
# 2015
# 84728
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.776
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:ADANIPOWER
# 2015
# 84734
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.792
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:BSOFT
# 2015
# 84725
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.768
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:ASHOKLEY
# 2015
# 84729
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77866666666668
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:NCC
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:BANKINDIA
# 2015
# 84728
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.776
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:FEDERALBNK
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:MOTHERSUMI
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:BANKBARODA
# 2015
# 84734
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.792
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:JINDALSTEL
# 2015
# 84727
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77333333333334
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:L&TFH
# 2015
# 84722
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:PFC
# 2015
# 84721
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.75733333333332
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:EQUITAS
# 2015
# Failed calculation for NSE:EQUITAS : 'timestamp'
# NSE:TATAMOTORS
# 2015
# 84724
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76533333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:TATAMOTORS : float division by zero
# NSE:IOC
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:ADANIENT
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91877
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 244.84533333333334
# Failed calculation for NSE:ADANIENT : float division by zero
# NSE:GAIL
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:VEDL
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:APOLLOTYRE
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:DLF
# 2015
# 84732
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78666666666666
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:HINDALCO
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:AMBUJACEM
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:HINDZINC
# 2015
# 84730
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78133333333332
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:CADILAHC
# 2015
# 84734
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.792
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:CADILAHC : float division by zero
# NSE:POWERGRID
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:HINDPETRO
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:HINDPETRO : float division by zero
# NSE:INFRATEL
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:INFRATEL : float division by zero
# NSE:ITC
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:PETRONET
# 2015
# 84725
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.768
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:TATAGLOBAL
# 2015
# 84728
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.776
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:UJJIVAN
# 2015
# Failed calculation for NSE:UJJIVAN : 'timestamp'
# NSE:TORNTPOWER
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:IGL
# 2015
# 84729
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77866666666668
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:ADANIPORTS
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:ADANIPORTS : float division by zero
# NSE:BERGEPAINT
# 2015
# 84731
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.784
# 2016
# 91934
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 244.99733333333333
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# NSE:BPCL
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:BPCL : float division by zero
# NSE:ZEEL
# 2015
# 84726
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77066666666667
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:ZEEL : float division by zero
# NSE:GLENMARK
# 2015
# 84733
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78933333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# Failed calculation for NSE:GLENMARK : 'DataFrame' object has no attribute 'dt'
# NSE:BHARTIARTL
# 2015
# 84729
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.77866666666668
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:BHARTIARTL : float division by zero
# NSE:TVSMOTOR
# 2015
# 84724
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.76533333333333
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:TVSMOTOR : float division by zero
# NSE:HEXAWARE
# 2015
# 84732
#            date  close  timestamp  high  low  open  volume  day
# 193  2015-11-11     62         62    62   62    62      62   62
# 225.78666666666666
# 2016
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 202  2016-10-30     60         60    60   60    60      60   60
# 245.0
# 2017
# 92490
#            date  close  timestamp  high  low  open  volume  day
# 128  2017-07-10    180        180   180  180   180     180  180
# 198  2017-10-19     60         60    60   60    60      60   60
# 246.0
# 2018
# 91935
#            date  close  timestamp  high  low  open  volume  day
# 210  2018-11-07     60         60    60   60    60      60   60
# 245.0
# Failed calculation for NSE:HEXAWARE : float division by zero
# NSE:ICICIPRULI
# 2015
# Failed calculation for NSE:ICICIPRULI : 'timestamp'

# %% [markdown]
# # High Trades Analysis

# %%
high_trades = all_trades[(all_trades['condition']=='high') & (all_trades['status']=='complete')]

# %%
high_trades_loop = pd.DataFrame()
for instrument in high_trades.instrument.unique().tolist():
    instrument_high_trades = high_trades[high_trades['instrument']==instrument]
    instrument_high_trades_loop = instrument_high_trades[instrument_high_trades['trade_number']<=instrument_high_trades[instrument_high_trades['pl_tag']==1.0].trade_number.max()]
    high_trades_loop = high_trades_loop.append(instrument_high_trades_loop, ignore_index=True)

# %%
high_trades.head()
# Out:
#       instrument  high_prev  low_prev  open_today condition transaction_type  \
# 2  NSE:UNIONBANK     176.20    167.60      177.50      high              buy
# 3  NSE:UNIONBANK     174.95    168.55      181.05      high              buy
# 5  NSE:UNIONBANK     170.75    166.50      171.05      high              buy
# 7  NSE:UNIONBANK     145.45    140.65      145.65      high              buy
# 8  NSE:UNIONBANK     149.20    142.85      149.50      high              buy
#
#   trade_number level  budget  return daily_khwab actual_khwab quantity  \
# 2            1     1   400.0    0.02           0            0        2
# 3            2     1   400.0    0.02           0            0        2
# 5            3     2   400.0    0.02           0          7.2        3
# 7            4     3   400.0    0.02           0          8.4        5
# 8            5     4   400.0    0.02           0         17.4       10
#
#    budget_required   price  trigger_price  squareoff  stoploss order_id  \
# 2           355.00  177.70         177.60        2.4       3.6        1
# 3           362.10  181.25         181.15        2.4       3.6        2
# 5           513.15  171.20         171.15        2.3       3.4        3
# 7           728.25  145.80         145.70        2.0       2.9        4
# 8          1495.00  149.65         149.55        2.0       3.0        5
#
#                    timestamp order_type    status  profit  pl_tag flag  \
# 2  2015-02-28 11:19:00+05:30         SL  complete     4.8     1.0    1
# 3  2015-03-04 11:04:00+05:30         SL  complete    -7.2    -1.0   -1
# 5  2015-03-17 15:09:00+05:30         SL  complete    -1.2    -0.1    0
# 7  2015-06-15 15:09:00+05:30         SL  complete    -9.0    -0.6    0
# 8  2015-06-17 09:45:00+05:30         SL  complete   -30.0    -1.0   -1
#
#    adhoora_khwab
# 2           -4.8
# 3            7.2
# 5            8.4
# 7           17.4
# 8           47.4

# %% [markdown]
# # Low Trades Analysis

# %%
low_trades = all_trades[(all_trades['condition']=='low') & (all_trades['status']=='complete')]

# %%
low_trades_loop = pd.DataFrame()
for instrument in low_trades.instrument.unique().tolist():
    instrument_low_trades = low_trades[low_trades['instrument']==instrument]
    instrument_low_trades_loop = instrument_low_trades[instrument_low_trades['trade_number']<=instrument_low_trades[instrument_low_trades['pl_tag']==1.0].trade_number.max()]
    low_trades_loop = low_trades_loop.append(instrument_low_trades_loop, ignore_index=True)

# %%
low_trades.head()
# Out:
#        instrument  high_prev  low_prev  open_today condition transaction_type  \
# 0   NSE:UNIONBANK     196.55    189.05      188.60       low             sell
# 1   NSE:UNIONBANK     189.95    176.15      175.50       low             sell
# 4   NSE:UNIONBANK     172.55    168.50      166.85       low             sell
# 6   NSE:UNIONBANK     145.80    136.10      135.70       low             sell
# 11  NSE:UNIONBANK     154.50    149.60      146.95       low             sell
#
#    trade_number level  budget  return daily_khwab actual_khwab quantity  \
# 0             1     1   400.0    0.02           0            0        2
# 1             2     1   400.0    0.02           0            0        2
# 4             3     1   400.0    0.02           0            0        2
# 6             4     2   400.0    0.02           0          6.6        4
# 11            5     1   400.0    0.02           0            0        2
#
#     budget_required   price  trigger_price  squareoff  stoploss order_id  \
# 0             377.2  188.40         188.50        2.5       3.8        1
# 1             351.0  175.30         175.40        2.4       3.5        2
# 4             333.7  166.70         166.75        2.3       3.3        3
# 6             542.8  135.55         135.65        1.8       2.7        4
# 11            293.9  146.80         146.90        2.0       2.9        5
#
#                     timestamp order_type    status  profit  pl_tag flag  \
# 0   2015-02-09 09:15:00+05:30         SL  complete     5.0     1.0    1
# 1   2015-02-10 09:15:00+05:30         SL  complete     4.8     1.0    1
# 4   2015-03-16 14:25:00+05:30         SL  complete    -6.6    -1.0   -1
# 6   2015-05-07 10:42:00+05:30         SL  complete     7.2     1.0    1
# 11  2015-06-29 09:21:00+05:30         SL  complete     4.0     1.0    1
#
#     adhoora_khwab
# 0            -5.0
# 1            -4.8
# 4             6.6
# 6            -0.6
# 11           -4.0

# %% [markdown]
# # Results

# %%
pd.DataFrame(data={'high':[len(high_trades),
                           len(high_trades_loop),
                           round(high_trades_loop.profit.sum(), 2), 
                           round(high_trades_loop.profit.sum()/budget_df.budget.sum() * 100, 2),
                           round(high_trades_loop.budget_required.max()), 
                           round(high_trades_loop.budget_required.max()/leverage)],
                   'low':[len(low_trades),
                          len(low_trades_loop),
                          round(low_trades_loop.profit.sum(), 2), 
                          round(low_trades_loop.profit.sum()/budget_df.budget.sum() * 100, 2),
                          round(low_trades_loop.budget_required.max()),
                          round(low_trades_loop.budget_required.max()/leverage)]
                   }, 
             index = ['total_trades', 'trades_considered', 'profit', 'perc_return', 'hightest_budget_required', 'hightest_margin_required'])
# Out:
#                                 high        low
# total_trades                 4828.00    3200.00
# trades_considered            4707.00    3102.00
# profit                      24882.79    7780.44
# perc_return                    88.55      27.69
# hightest_budget_required  4162320.00  260455.00
# hightest_margin_required   277488.00   17364.00

# %%
# high_trades[high_trades['budget_required']==high_trades['budget_required'].max()]

# %%
# high_trades[high_trades['instrument']=='NSE:TATAGLOBAL']

# %%
#high_trades.sort_values('budget_required', ascending=False)

# %% [markdown]
# # Daily Margin Required Analysis

# %%
all_trades['date'] = all_trades['timestamp'].dt.date
all_trades['margin_required'] = all_trades['budget_required']/leverage

# %%
import numpy as np
import matplotlib.pyplot as plt

def stacked_bar(data, series_labels, category_labels=None, 
                show_values=False, value_format="{}", y_label=None, 
                grid=True, reverse=False):
    """Plots a stacked bar chart with the data and labels provided.

    Keyword arguments:
    data            -- 2-dimensional numpy array or nested list
                       containing data for each series in rows
    series_labels   -- list of series labels (these appear in
                       the legend)
    category_labels -- list of category labels (these appear
                       on the x-axis)
    show_values     -- If True then numeric value labels will 
                       be shown on each bar
    value_format    -- Format string for numeric value labels
                       (default is "{}")
    y_label         -- Label for y-axis (str)
    grid            -- If True display grid
    reverse         -- If True reverse the order that the
                       series are displayed (left-to-right
                       or right-to-left)
    """

    ny = len(data[0])
    ind = list(range(ny))

    axes = []
    cum_size = np.zeros(ny)

    data = np.array(data)

    if reverse:
        data = np.flip(data, axis=1)
        category_labels = reversed(category_labels)

    for i, row_data in enumerate(data):
        axes.append(plt.bar(ind, row_data, bottom=cum_size, 
                            label=series_labels[i]))
        cum_size += row_data

    if category_labels:
        plt.xticks(ind, category_labels, rotation='vertical')

    if y_label:
        plt.ylabel(y_label)

    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    if grid:
        plt.grid()

    if show_values:
        for axis in axes:
            for bar in axis:
                w, h = bar.get_width(), bar.get_height()
                plt.text(bar.get_x() + w/2, bar.get_y() + h/2, 
                         value_format.format(h), ha="center", 
                         va="center")

# %%
df2 = all_trades.groupby(['date', 'instrument'])['margin_required'].sum().unstack('instrument').fillna(0)

df = df2.transpose()

plt.figure(figsize=(50, 10))

series_labels = df.index.tolist()

data = df.values

category_labels = df.columns.tolist()

stacked_bar(
    data, 
    series_labels, 
    category_labels=category_labels, 
    show_values=False,
    value_format="{:.1f}",
    y_label="Total margin required"
)

plt.savefig('margin_required_oneper_final_{}_{}_{}_{}.png'.format(from_year, to_year, par_1, par_2))
plt.show()

# %%
margins = all_trades.groupby('date').agg({'budget_required':sum, 'margin_required':sum, 'profit':sum, 'instrument':list, 'instrument':pd.Series.nunique}).reset_index()
margins['cum_profit'] = margins['profit'].cumsum()
margins['available_margin'] = 28000 + margins['cum_profit'].shift(1)
margins.fillna(28000, inplace=True)
margins['trade_feasibility'] = margins['available_margin']-margins['margin_required']

# %%
margins.sort_values('instrument', ascending=False)
# Out:
#            date  budget_required  margin_required    profit  instrument  \
# 429  2016-11-09         31178.44      2078.562667    227.80          53
# 338  2016-06-24        227050.63     15136.708667   2561.45          52
# 764  2018-03-23         40936.06      2729.070667     72.37          48
# 262  2016-03-02        120792.84      8052.856000    565.68          44
# 242  2016-02-03         28922.01      1928.134000    207.55          44
# 97   2015-06-29         58944.57      3929.638000   -441.15          43
# 136  2015-08-24         44303.31      2953.554000    341.70          43
# 391  2016-09-12         41156.02      2743.734667    469.82          43
# 430  2016-11-10        116736.24      7782.416000   1443.39          42
# 135  2015-08-21         59942.90      3996.193333    470.32          42
# 186  2015-11-09         28553.87      1903.591333   -351.52          41
# 102  2015-07-06        111841.70      7456.113333  -2119.63          41
# 156  2015-09-23         41018.58      2734.572000   -440.74          41
# 159  2015-09-29         56751.61      3783.440667    293.43          41
# 514  2017-03-14         53418.32      3561.221333   -139.66          39
# 224  2016-01-07         74023.42      4934.894667    845.93          39
# 246  2016-02-09         19821.27      1321.418000    -48.22          38
# 306  2016-05-11         65053.75      4336.916667   -135.56          38
# 104  2015-07-08        289665.91     19311.060667   3670.69          38
# 253  2016-02-18         61800.35      4120.023333   -346.88          38
# 329  2016-06-13         60530.67      4035.378000    -55.02          38
# 454  2016-12-15         26271.34      1751.422667   -369.70          37
# 732  2018-02-05         16733.73      1115.582000    -75.90          37
# 679  2017-11-17        116436.69      7762.446000    251.94          37
# 50      -237.40          27766.70       27728.904667
# 882    28657.10          56648.60       56606.630000
# 742    26074.17          54080.47       54021.593333
# 599    24540.13          52532.53       52426.843333
# 381    21556.35          49563.49       49318.786000
# 834    27129.75          55142.45       54297.600000
# 833    27142.45          55132.35       55080.046667
# 841    26224.91          54203.61       54096.840000
# 541    23842.21          51578.91       50316.970000
# 492    24029.73          51827.97       50811.917333
# 880    28646.95          56640.85       56603.306667
# 811    27441.61          55462.11       55392.810000
# 395    22392.20          50390.05       50345.160000
# 853    28726.41          56722.31       56602.643333
# 313   -19661.23           8339.23        8301.698667
# 273     1508.93          29503.53       29432.930000
# 535    23547.06          51157.56       49215.440000
# 191     1741.24          29745.84       29703.040000
# 722    25581.50          53588.25       53555.120000
# 220     1588.74          29609.24       29471.580000
# 489    23849.49          51860.69       51775.890000
# 491    23827.97          51817.17       51764.236667
# 105    -1038.69          27048.01       26651.876000
# 549    23712.65          51709.15       51676.843333
# 863    28583.31          56579.86       56303.540000
# 254     5148.14          33150.24       33105.563333
# 96     -2801.72          25197.18       25152.184000
# 181     2198.74          30204.64       30185.106667
# 302   -19604.97           8432.83        8307.490000
# 631    24377.55          52250.80       46744.780000
# 757    25794.05          53794.05       53768.090000
# 145     1523.03          29515.83       29480.690000
# 374    16210.58          44217.66       44174.566667
# 638    24215.21          52201.01       52057.676667
# 54      -484.00          27506.10       27457.050000
# 644    25107.13          53102.63       53079.980000
# 567    24750.96          52750.26       52730.086667
# 455    23189.86          51189.86       51163.520000
# 927    30302.95          58318.55       58267.190000
# 142     1514.45          29542.35       29449.974000
# 583    24516.05          52512.90       52456.806667
# 893    29026.30          57017.90       56976.850000
# 887    29166.60          57109.60       56828.400000
# 417    21976.63          49973.03       49947.096667
# 212     2332.47          30332.82       30318.965333
# 846    25348.81          53348.81       51338.143333
# 707    26317.66          54324.86       54300.260000
# 126      748.37          28748.37       28629.570000
# 698    26111.37          54114.02       54098.102000
# 777    27958.98          55959.88       55938.013333
# 879    28640.85          56635.45       56609.350000
# 727    25643.70          53508.40       52839.600000
# 610    24368.93          52346.93       52238.066667
# 80     -1313.06          26694.54       26669.806667
# 873    28710.13          56708.79       56693.870000
# 232      713.50          28719.40       28699.686667
# 437    23702.20          51709.80       51684.790667
# 21      -576.27          27423.73       27399.886667
# 73      -777.33          27222.67       27184.470000
# 55      -488.90          27516.00       27499.700000

# %%
plt.figure(figsize=(20, 5))
plt.plot(margins['date'], margins['available_margin'])
plt.plot(margins['date'], margins['margin_required'])
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
margins.head()
# Out:
#          date  budget_required  margin_required  profit  instrument  \
# 0  2015-02-03          3029.81       201.987333  -48.50           9
# 1  2015-02-04          3081.85       205.456667  -23.72          10
# 2  2015-02-06          1354.75        90.316667    2.40           4
# 3  2015-02-09          8068.59       537.906000   -5.20          23
# 4  2015-02-10          7678.57       511.904667  -44.00          20
#
#    cum_profit  available_margin  trade_feasibility
# 0      -48.50          28000.00       27798.012667
# 1      -72.22          27951.50       27746.043333
# 2      -69.82          27927.78       27837.463333
# 3      -75.02          27930.18       27392.274000
# 4     -119.02          27924.98       27413.075333
